# %% [markdown]
# # Training a Model for each Feature List
#
# In this notebook, we train a diffrent lag_reg_ensemble model with different list of features chosen based on our clustering data. Then each model is evaluated on the test set and saved; we will ensemble all these models using ridge regression in a diffrerent notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, SGDRegressor, LinearRegression
from sklearn.preprocessing import StandardScaler
import os
import gc
import warnings
from tqdm.notebook import tqdm
import time
from collections import defaultdict
warnings.filterwarnings('ignore')

# %%
class IncrementalLagEnsemble:
    """Incrementally trains models on different lag configurations using SGD."""
    
    def __init__(self, feature_batch_size=20, lag_batch_size=5, n_epochs=9):
        self.feature_batch_size = feature_batch_size
        self.lag_batch_size = lag_batch_size
        self.n_epochs = n_epochs  
        self.models = {}
        self.scalers = {}
        self.feature_names = None
        self.performance_history = defaultdict(list)
        
        # Define lag strategies with odd/even splits for many configurations
        self.lag_strategies = {
            # Original micro lags
            'micro': [1, 2, 3, 4, 5],
            'micro_odd': [1, 3, 5, 7, 9],
            'micro_even': [2, 4, 6, 8, 10],
            
            # Ultra short with odd/even
            'ultra_short': [6, 8, 10, 12, 15],
            'ultra_short_odd': [7, 9, 11, 13, 15, 17],
            'ultra_short_even': [6, 8, 10, 12, 14, 16],
            
            # Short with odd/even
            'short': [20, 25, 30, 40, 50],
            'short_odd': [21, 25, 31, 41, 51],
            'short_even': [20, 24, 30, 40, 50],
            
            # Short medium with odd/even
            'short_medium': [60, 75, 90, 105, 120],
            'short_medium_odd': [61, 75, 91, 105, 121],
            'short_medium_even': [60, 74, 90, 104, 120],
            
            # Medium with odd/even
            'medium': [150, 180, 210, 240, 300],
            'medium_odd': [151, 181, 211, 241, 301],
            
            # Medium long with odd/even
            'medium_long': [360, 420, 480, 540, 600],
            'medium_long_odd': [361, 421, 481, 541, 601],
            
            # Long with odd/even
            'long': [720, 840, 960, 1080, 1200],
            'long_odd': [721, 841, 961, 1081, 1201],
            
            # Very long with odd/even
            'very_long': [1440, 1800, 2160, 2520, 2880],
            'very_long_odd': [1441, 1801, 2161, 2521, 2881],
            
            # Ultra long (keeping original only due to very large values)
            'ultra_long': [3600, 4320, 5040, 5760, 7200]
        }
        
    def create_lag_features_batch(self, df, lag_list):
        """Create lag features for a batch of lags."""
        lag_features = []
        
        for lag in lag_list:
            lagged = df.shift(-lag)
            lagged.columns = [f'{col}_lag_{lag}' for col in df.columns]
            lag_features.append(lagged)
        
        result = pd.concat([df] + lag_features, axis=1)
        result = result.fillna(0)
        
        return result
    
    def train_sgd_model(self, X, y, model_name):
        """Train SGD model incrementally with more epochs."""
        print(f"  Training SGD model: {model_name} ({self.n_epochs} epochs)")
        
        # Initialize model and scaler if not exists
        if model_name not in self.models:
            self.models[model_name] = SGDRegressor(
                loss='huber',
                penalty='elasticnet',
                alpha=0.0001,
                l1_ratio=0.15,
                learning_rate='invscaling',
                eta0=0.01,
                power_t=0.25,
                random_state=42,
                warm_start=True,
                max_iter=1000,
                tol=1e-3
            )
            self.scalers[model_name] = StandardScaler()
            
        model = self.models[model_name]
        scaler = self.scalers[model_name]
        
        # Train in epochs with smaller chunks for better convergence
        chunk_size = 25000  # Slightly smaller chunks for more updates
        for epoch in range(self.n_epochs):
            # Shuffle indices for each epoch
            indices = np.random.permutation(len(X))
            
            for start_idx in range(0, len(X), chunk_size):
                end_idx = min(start_idx + chunk_size, len(X))
                
                # Get shuffled chunk
                chunk_indices = indices[start_idx:end_idx]
                X_chunk = X.iloc[chunk_indices]
                y_chunk = y[chunk_indices]
                
                # Scale
                if start_idx == 0 and epoch == 0:
                    X_scaled = scaler.fit_transform(X_chunk)
                else:
                    X_scaled = scaler.transform(X_chunk)

                
                # Partial fit
                model.partial_fit(X_scaled, y_chunk)

            # Print progress
            if epoch % 3 == 0:
                print(f"    Epoch {epoch+1}/{self.n_epochs} completed")
        
        return model
    
    def train_feature_batch(self, feature_batch, X_full, y, strategy_name, lag_list):
        """Train on a batch of features with specific lags."""
        print(f"\n  Processing feature batch ({len(feature_batch)} features) with {strategy_name} lags")
        
        # Select feature batch
        X_batch = X_full[feature_batch].copy()
        
        # Create lag features
        X_with_lags = self.create_lag_features_batch(X_batch, lag_list)
        
        # Train SGD model
        model_name = f"{strategy_name}_{feature_batch[0]}_{feature_batch[-1]}"
        self.train_sgd_model(X_with_lags, y, model_name)
        
        # Clean up
        del X_batch, X_with_lags
        gc.collect()
        
    def fit(self, X, y):
        """Fit ensemble using incremental training."""
        print("Training Incremental Lag Ensemble with Odd/Even Lag Configurations...")
        print(f"Total epochs per model: {self.n_epochs}")
        
        self.feature_names = X.columns.tolist()
        n_features = len(self.feature_names)
        
        # Split features into batches
        feature_batches = []
        for i in range(0, n_features, self.feature_batch_size):
            batch = self.feature_names[i:i+self.feature_batch_size]
            feature_batches.append(batch)
        
        print(f"Split {n_features} features into {len(feature_batches)} batches")
        print(f"Total lag strategies (including odd/even): {len(self.lag_strategies)}")
        
        # Calculate total lag values
        total_lags = sum(len(lags) for lags in self.lag_strategies.values())
        print(f"Total unique lag values: {total_lags}")
        
        # Train models for each combination of feature batch and lag strategy
        total_models = len(feature_batches) * len(self.lag_strategies)
        model_count = 0
        
        for strategy_name, lag_list in self.lag_strategies.items():
            print(f"\nTraining {strategy_name} strategy (lags: {lag_list})")
            
            for batch_idx, feature_batch in enumerate(feature_batches):
                model_count += 1
                print(f"Progress: {model_count}/{total_models} models")
                
                self.train_feature_batch(feature_batch, X, y, strategy_name, lag_list)
                
                # Clean up periodically
                if batch_idx % 2 == 0:
                    gc.collect()
        
        
        print(f"\nTotal models trained: {len(self.models)}")
        
    def predict_batch(self, X, feature_batch, strategy_name, lag_list):
        """Make predictions for a specific feature batch and lag strategy."""
        model_name = f"{strategy_name}_{feature_batch[0]}_{feature_batch[-1]}"
        
        if model_name not in self.models:
            return None
            
        # Select features
        X_batch = X[feature_batch].copy()
        
        # Create lag features
        X_with_lags = self.create_lag_features_batch(X_batch, lag_list)
        
        # Scale and predict
        X_scaled = self.scalers[model_name].transform(X_with_lags)
        predictions = self.models[model_name].predict(X_scaled)
        
        # Clean up
        del X_batch, X_with_lags, X_scaled
        gc.collect()
        
        return predictions
    
    def predict(self, X):
        """Make ensemble predictions."""
        all_predictions = {}
        
        # Recreate feature batches
        n_features = len(self.feature_names)
        feature_batches = []
        for i in range(0, n_features, self.feature_batch_size):
            batch = self.feature_names[i:i+self.feature_batch_size]
            if all(col in X.columns for col in batch):
                feature_batches.append(batch)
        
        # Get predictions from each model
        for strategy_name, lag_list in self.lag_strategies.items():
            for feature_batch in feature_batches:
                pred = self.predict_batch(X, feature_batch, strategy_name, lag_list)
                if pred is not None:
                    model_name = f"{strategy_name}_{feature_batch[0]}_{feature_batch[-1]}"
                    all_predictions[model_name] = pred
        
        return pd.DataFrame(all_predictions)

# %% [markdown]
# ## Find the Features_list Based on the X Clusters
#
# We sample one by one from each cluster untill all the X features are sampled. We remove the ones with less than 10 features in them.

# %%
clusters = pd.read_csv('clusters.csv', index_col=0)

clusters_dict = defaultdict(list)

for c in np.unique(clusters):
    X = clusters[clusters['0'] == c]
    clusters_dict[c] = X.index.tolist()

total = 0

features_list = []

while total<780:
    features = []
    for k in clusters_dict.keys():
        if len(clusters_dict[k])>0:
            features.append(clusters_dict[k][-1])
            clusters_dict[k].pop()
            total += 1
    features_list.append(features)
    features = list([])
while len(features_list[-1])<10:
    features_list.pop()

# %%
train = pd.read_parquet('data/train.parquet')

test = pd.read_parquet('data/test.parquet')

order_features = train.columns.tolist()[:5]

Y = train['label']

# %%
row_id = pd.read_csv('closest_rows.csv', index_col=0)

new = test.reset_index()

new['row_id'] = row_id['0']

new.head()
# Out:
#    ID  bid_qty  ask_qty  buy_qty  sell_qty   volume        X1        X2  \
# 0   1    0.317    8.102   13.164    10.272   23.436 -0.341229  0.041851
# 1   2    2.608    2.111  123.562    40.163  163.725 -1.029564 -1.382505
# 2   3    2.768   10.787  126.137   118.266  244.403 -2.594090 -5.486158
# 3   4    0.948   12.157   16.069    31.723   47.792  0.240745  0.997585
# 4   5    1.084    3.493   32.679    37.327   70.006  0.067189  0.772852
#
#          X3        X4  ...      X773      X774      X775      X776      X777  \
# 0 -0.020094 -0.206221  ... -0.043417  1.521787  1.548965  1.495735  1.166730
# 1 -1.214935 -1.020241  ... -0.077090 -0.703054 -0.716951 -0.721292 -0.674619
# 2 -4.744466 -3.930152  ... -0.030627 -0.703514 -0.717525 -0.731701 -0.750998
# 3  1.028965  1.081052  ... -0.033380  1.521167  1.551771  1.582833  1.625830
# 4  0.772152  0.714846  ... -0.004915 -0.703161 -0.716900 -0.714699 -0.652209
#
#        X778      X779      X780  label  row_id
# 0  0.281056 -0.187831 -0.599553      0  112334
# 1 -0.639318 -0.736268 -0.862220      0   69300
# 2 -0.789366 -0.850941 -1.033131      0  152075
# 3  1.762155  1.911924  1.962445      0  255828
# 4 -0.623165 -0.699887 -0.640094      0  390226
#
# [5 rows x 788 columns]

# %%
new = new.sort_values('row_id')

new.head()
# Out:
#             ID  bid_qty  ask_qty  buy_qty  sell_qty   volume        X1  \
# 192617  192618    1.037   20.607   20.377    18.854   39.231  1.907120
# 188498  188499   24.169    2.624    7.885     9.266   17.151  0.555521
# 424484  424485    9.500   10.256   27.151    12.778   39.929  0.696916
# 424482  424483    1.910    4.205  121.387    90.664  212.051  1.207702
# 268120  268121    4.567    4.285   37.114    25.157   62.271 -1.007777
#
#               X2        X3        X4  ...      X773      X774      X775  \
# 192617  0.428308  0.981918  1.342953  ... -0.046392  1.523177  1.547193
# 188498  0.461120  0.728130  0.766869  ... -0.012611  1.522990  1.553631
# 424484 -0.095659 -0.216179 -0.155187  ... -0.017567 -0.703437 -0.717389
# 424482  0.990580  1.029870  1.112571  ... -0.046124 -0.703374 -0.669391
# 268120 -0.636524 -0.791924 -0.824496  ... -0.025530  1.521299  1.551170
#
#             X776      X777      X778      X779      X780  label  row_id
# 192617  1.462730  1.084867  0.196849 -0.249480 -0.644863      0      -1
# 188498  1.584729  1.626858  1.580276  1.221571  0.683121      0      -1
# 424484 -0.731427 -0.747933 -0.755011 -0.796735 -0.778168      0      -1
# 424482 -0.506669 -0.386120 -0.519117 -0.647202 -0.578245      0      -1
# 268120  1.542630  1.314757  0.461959 -0.050952 -0.498569      0      -1
#
# [5 rows x 788 columns]

# %% [markdown]
# ## Include the Order Book Data
#
# We include the order book data in all the models.

# %%
X_trains = {}

X_tests = {}

for i in range(len(features_list)):
    X_trains[i] = train[order_features+features_list[i]]
    X_tests[i] = new[order_features+features_list[i]]

# %% [markdown]
# ## Training the Models
#
# Each model is trained and evaluated on the test set; we store each test prediction in a parquet file. For each model, we use a different feature batch size based on the number of features in the specific features_list used for that model.

# %%
# %%time

train_preds = []

test_preds = []

for i in [0,1,2]:
    ensemble = IncrementalLagEnsemble(
      feature_batch_size=20,  # Slightly smaller batches due to more features
      lag_batch_size=5,
      n_epochs=9  # Increased to 9 as requested
    )

    ensemble.fit(X_trains[i], Y)

    train_preds.append(ensemble.predict(X_trains[i]))

    test_preds.append(ensemble.predict(X_tests[i]))

    print()
    print(f"Model {i} Finished")
    print()

    del ensemble
    gc.collect()

train_preds = pd.concat(train_preds, axis=1)
test_preds = pd.concat(test_preds, axis=1)

train_preds.to_parquet('train_preds_[0,1,2].parquet')
test_preds.to_parquet('test_preds_[0,1,2].parquet')

del test_preds, train_preds
gc.collect()
# Out:
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 179 features into 9 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 2/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 3/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 4/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 5/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 6/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 7/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 8/189 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 9/189 models
#
#   Processing feature batch (19 features) with micro lags
#   Training SGD model: micro_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 10/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 11/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 12/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 13/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 14/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 15/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 16/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 17/189 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 18/189 models
#
#   Processing feature batch (19 features) with micro_odd lags
#   Training SGD model: micro_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 19/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 20/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 21/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 22/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 23/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 24/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 25/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 26/189 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 27/189 models
#
#   Processing feature batch (19 features) with micro_even lags
#   Training SGD model: micro_even_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 28/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 29/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 30/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 31/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 32/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 33/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 34/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 35/189 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 36/189 models
#
#   Processing feature batch (19 features) with ultra_short lags
#   Training SGD model: ultra_short_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 37/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 38/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 39/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 40/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 41/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 42/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 43/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 44/189 models
#
#   Processing feature batch (20 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 45/189 models
#
#   Processing feature batch (19 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 46/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 47/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 48/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 49/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 50/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 51/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 52/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 53/189 models
#
#   Processing feature batch (20 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 54/189 models
#
#   Processing feature batch (19 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 55/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 56/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 57/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 58/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 59/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 60/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 61/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 62/189 models
#
#   Processing feature batch (20 features) with short lags
#   Training SGD model: short_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 63/189 models
#
#   Processing feature batch (19 features) with short lags
#   Training SGD model: short_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 64/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 65/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 66/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 67/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 68/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 69/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 70/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 71/189 models
#
#   Processing feature batch (20 features) with short_odd lags
#   Training SGD model: short_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 72/189 models
#
#   Processing feature batch (19 features) with short_odd lags
#   Training SGD model: short_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 73/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 74/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 75/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 76/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 77/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 78/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 79/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 80/189 models
#
#   Processing feature batch (20 features) with short_even lags
#   Training SGD model: short_even_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 81/189 models
#
#   Processing feature batch (19 features) with short_even lags
#   Training SGD model: short_even_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 82/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 83/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 84/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 85/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 86/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 87/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 88/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 89/189 models
#
#   Processing feature batch (20 features) with short_medium lags
#   Training SGD model: short_medium_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 90/189 models
#
#   Processing feature batch (19 features) with short_medium lags
#   Training SGD model: short_medium_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 91/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 92/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 93/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 94/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 95/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 96/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 97/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 98/189 models
#
#   Processing feature batch (20 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 99/189 models
#
#   Processing feature batch (19 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 100/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 101/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 102/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 103/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 104/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 105/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 106/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 107/189 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 108/189 models
#
#   Processing feature batch (19 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 109/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 110/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 111/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 112/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 113/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 114/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 115/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 116/189 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 117/189 models
#
#   Processing feature batch (19 features) with medium lags
#   Training SGD model: medium_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 118/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 119/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 120/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 121/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 122/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 123/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 124/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 125/189 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 126/189 models
#
#   Processing feature batch (19 features) with medium_odd lags
#   Training SGD model: medium_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 127/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 128/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 129/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 130/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 131/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 132/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 133/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 134/189 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 135/189 models
#
#   Processing feature batch (19 features) with medium_long lags
#   Training SGD model: medium_long_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 136/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 137/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 138/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 139/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 140/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 141/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 142/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 143/189 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 144/189 models
#
#   Processing feature batch (19 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 145/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 146/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 147/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 148/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 149/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 150/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 151/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 152/189 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 153/189 models
#
#   Processing feature batch (19 features) with long lags
#   Training SGD model: long_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 154/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 155/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 156/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 157/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 158/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 159/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 160/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 161/189 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 162/189 models
#
#   Processing feature batch (19 features) with long_odd lags
#   Training SGD model: long_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 163/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 164/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 165/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 166/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 167/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 168/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 169/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 170/189 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 171/189 models
#
#   Processing feature batch (19 features) with very_long lags
#   Training SGD model: very_long_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 172/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 173/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 174/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 175/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 176/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 177/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 178/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 179/189 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 180/189 models
#
#   Processing feature batch (19 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 181/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X501 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 182/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X498_X715 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 183/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X727_X685 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 184/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X653_X97 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 185/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X79_X163 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 186/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X408_X268 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 187/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X364_X181 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 188/189 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X629_X751 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 189/189 models
#
#   Processing feature batch (19 features) with ultra_long lags
#   Training SGD model: ultra_long_X587_X519 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 189
#
# Model 0 Finished
#
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 144 features into 8 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/168 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_bid_qty_X497 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 2/168 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X507_X710 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 3/168 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X654_X171 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 4/168 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X18_X402 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 5/168 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X155_X467 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 6/168 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X462_X361 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 7/168 models
#
#   Processing feature batch (20 features) with micro lags
#   Training SGD model: micro_X337_X510 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 8/168 models
#
#   Processing feature batch (4 features) with micro lags
#   Training SGD model: micro_X546_X549 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 9/168 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X497 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 10/168 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X507_X710 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 11/168 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X654_X171 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 12/168 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X18_X402 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 13/168 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X155_X467 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 14/168 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X462_X361 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 15/168 models
#
#   Processing feature batch (20 features) with micro_odd lags
#   Training SGD model: micro_odd_X337_X510 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 16/168 models
#
#   Processing feature batch (4 features) with micro_odd lags
#   Training SGD model: micro_odd_X546_X549 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 17/168 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X497 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 18/168 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X507_X710 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 19/168 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X654_X171 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 20/168 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X18_X402 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 21/168 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X155_X467 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 22/168 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X462_X361 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 23/168 models
#
#   Processing feature batch (20 features) with micro_even lags
#   Training SGD model: micro_even_X337_X510 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 24/168 models
#
#   Processing feature batch (4 features) with micro_even lags
#   Training SGD model: micro_even_X546_X549 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 25/168 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X497 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 26/168 models
#
#   Processing feature batch (20 features) with ultra_short lags
#   Training SGD model: ultra_short_X507_X710 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# ...
#   Training SGD model: short_medium_odd_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 78/147 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 79/147 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 80/147 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 81/147 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 82/147 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 83/147 models
#
#   Processing feature batch (20 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 84/147 models
#
#   Processing feature batch (2 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 85/147 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 86/147 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 87/147 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 88/147 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 89/147 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 90/147 models
#
#   Processing feature batch (20 features) with medium lags
#   Training SGD model: medium_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 91/147 models
#
#   Processing feature batch (2 features) with medium lags
#   Training SGD model: medium_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 92/147 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 93/147 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 94/147 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 95/147 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 96/147 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 97/147 models
#
#   Processing feature batch (20 features) with medium_odd lags
#   Training SGD model: medium_odd_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 98/147 models
#
#   Processing feature batch (2 features) with medium_odd lags
#   Training SGD model: medium_odd_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 99/147 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 100/147 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 101/147 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 102/147 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 103/147 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 104/147 models
#
#   Processing feature batch (20 features) with medium_long lags
#   Training SGD model: medium_long_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 105/147 models
#
#   Processing feature batch (2 features) with medium_long lags
#   Training SGD model: medium_long_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 106/147 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 107/147 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 108/147 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 109/147 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 110/147 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 111/147 models
#
#   Processing feature batch (20 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 112/147 models
#
#   Processing feature batch (2 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 113/147 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 114/147 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 115/147 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 116/147 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 117/147 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 118/147 models
#
#   Processing feature batch (20 features) with long lags
#   Training SGD model: long_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 119/147 models
#
#   Processing feature batch (2 features) with long lags
#   Training SGD model: long_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 120/147 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 121/147 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 122/147 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 123/147 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 124/147 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 125/147 models
#
#   Processing feature batch (20 features) with long_odd lags
#   Training SGD model: long_odd_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 126/147 models
#
#   Processing feature batch (2 features) with long_odd lags
#   Training SGD model: long_odd_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 127/147 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 128/147 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 129/147 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 130/147 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 131/147 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 132/147 models
#
#   Processing feature batch (20 features) with very_long lags
#   Training SGD model: very_long_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 133/147 models
#
#   Processing feature batch (2 features) with very_long lags
#   Training SGD model: very_long_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 134/147 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 135/147 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 136/147 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 137/147 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 138/147 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 139/147 models
#
#   Processing feature batch (20 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 140/147 models
#
#   Processing feature batch (2 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 141/147 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X664 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 142/147 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X636_X58 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 143/147 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X148_X396 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 144/147 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X149_X461 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 145/147 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X475_X331 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 146/147 models
#
#   Processing feature batch (20 features) with ultra_long lags
#   Training SGD model: ultra_long_X313_X561 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 147/147 models
#
#   Processing feature batch (2 features) with ultra_long lags
#   Training SGD model: ultra_long_X582_X543 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 147
#
# Model 2 Finished
#
# CPU times: user 1h 11min 39s, sys: 28min 23s, total: 1h 40min 3s
# Wall time: 1h 2min 27s
# 0

# %%
# %%time

train_preds = []

test_preds = []

for i in [3,4,5,7]:
    ensemble = IncrementalLagEnsemble(
      feature_batch_size=15,  # Slightly smaller batches due to more features
      lag_batch_size=5,
      n_epochs=9  # Increased to 9 as requested
    )

    ensemble.fit(X_trains[i], Y)

    train_preds.append(ensemble.predict(X_trains[i]))

    test_preds.append(ensemble.predict(X_tests[i]))

    print()
    print(f"Model {i} Finished")
    print()

    del ensemble
    gc.collect()

train_preds = pd.concat(train_preds, axis=1)
test_preds = pd.concat(test_preds, axis=1)

train_preds.to_parquet('train_preds_[3,4,5,7].parquet')
test_preds.to_parquet('test_preds_[3,4,5,7].parquet')

del test_preds, train_preds
gc.collect()
# Out:
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 89 features into 6 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/126 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 2/126 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 3/126 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 4/126 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 5/126 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 6/126 models
#
#   Processing feature batch (14 features) with micro lags
#   Training SGD model: micro_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 7/126 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 8/126 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 9/126 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 10/126 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 11/126 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 12/126 models
#
#   Processing feature batch (14 features) with micro_odd lags
#   Training SGD model: micro_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 13/126 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 14/126 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 15/126 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 16/126 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 17/126 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 18/126 models
#
#   Processing feature batch (14 features) with micro_even lags
#   Training SGD model: micro_even_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 19/126 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 20/126 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 21/126 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 22/126 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 23/126 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 24/126 models
#
#   Processing feature batch (14 features) with ultra_short lags
#   Training SGD model: ultra_short_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 25/126 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 26/126 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 27/126 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 28/126 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 29/126 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 30/126 models
#
#   Processing feature batch (14 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 31/126 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 32/126 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 33/126 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 34/126 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 35/126 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 36/126 models
#
#   Processing feature batch (14 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 37/126 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 38/126 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 39/126 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 40/126 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 41/126 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 42/126 models
#
#   Processing feature batch (14 features) with short lags
#   Training SGD model: short_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 43/126 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 44/126 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 45/126 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 46/126 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 47/126 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 48/126 models
#
#   Processing feature batch (14 features) with short_odd lags
#   Training SGD model: short_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 49/126 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 50/126 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 51/126 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 52/126 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 53/126 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 54/126 models
#
#   Processing feature batch (14 features) with short_even lags
#   Training SGD model: short_even_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 55/126 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 56/126 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 57/126 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 58/126 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 59/126 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 60/126 models
#
#   Processing feature batch (14 features) with short_medium lags
#   Training SGD model: short_medium_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 61/126 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 62/126 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 63/126 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 64/126 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 65/126 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 66/126 models
#
#   Processing feature batch (14 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 67/126 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 68/126 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 69/126 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 70/126 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 71/126 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 72/126 models
#
#   Processing feature batch (14 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 73/126 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 74/126 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 75/126 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 76/126 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 77/126 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 78/126 models
#
#   Processing feature batch (14 features) with medium lags
#   Training SGD model: medium_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 79/126 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 80/126 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 81/126 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 82/126 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 83/126 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 84/126 models
#
#   Processing feature batch (14 features) with medium_odd lags
#   Training SGD model: medium_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 85/126 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 86/126 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 87/126 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 88/126 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 89/126 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 90/126 models
#
#   Processing feature batch (14 features) with medium_long lags
#   Training SGD model: medium_long_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 91/126 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 92/126 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 93/126 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 94/126 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 95/126 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 96/126 models
#
#   Processing feature batch (14 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 97/126 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 98/126 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 99/126 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 100/126 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 101/126 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 102/126 models
#
#   Processing feature batch (14 features) with long lags
#   Training SGD model: long_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 103/126 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 104/126 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 105/126 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 106/126 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 107/126 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 108/126 models
#
#   Processing feature batch (14 features) with long_odd lags
#   Training SGD model: long_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 109/126 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 110/126 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 111/126 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 112/126 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 113/126 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 114/126 models
#
#   Processing feature batch (14 features) with very_long lags
#   Training SGD model: very_long_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 115/126 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 116/126 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 117/126 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 118/126 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 119/126 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 120/126 models
#
#   Processing feature batch (14 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 121/126 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X502 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 122/126 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X660_X24 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 123/126 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X135_X119 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 124/126 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X324_X470 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 125/126 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X102_X301 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 126/126 models
#
#   Processing feature batch (14 features) with ultra_long lags
#   Training SGD model: ultra_long_X434_X537 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 126
#
# Model 3 Finished
#
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 60 features into 4 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/84 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 2/84 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 3/84 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 4/84 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 5/84 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 6/84 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 7/84 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 8/84 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 9/84 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 10/84 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 11/84 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 12/84 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 13/84 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 14/84 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 15/84 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 16/84 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 17/84 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 18/84 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 19/84 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 20/84 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 21/84 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 22/84 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 23/84 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 24/84 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 25/84 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 26/84 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 27/84 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 28/84 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 29/84 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 30/84 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 31/84 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 32/84 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 33/84 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 34/84 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 35/84 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 36/84 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 37/84 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 38/84 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 39/84 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 40/84 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 41/84 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 42/84 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 43/84 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 44/84 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 45/84 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 46/84 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 47/84 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 48/84 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 49/84 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 50/84 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 51/84 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 52/84 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 53/84 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 54/84 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 55/84 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 56/84 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 57/84 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 58/84 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 59/84 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 60/84 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 61/84 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 62/84 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 63/84 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 64/84 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 65/84 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 66/84 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 67/84 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 68/84 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 69/84 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 70/84 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 71/84 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 72/84 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 73/84 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 74/84 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 75/84 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 76/84 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 77/84 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 78/84 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 79/84 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 80/84 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X368_X525 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 81/84 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X731 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 82/84 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X675_X363 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 83/84 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X621_X218 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 84/84 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X368_X525 (9 epochs)
# ...
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 62/84 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X674_X115 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 63/84 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X107_X375 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 64/84 models
#
#   Processing feature batch (12 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X127_X570 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 65/84 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_bid_qty_X730 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 66/84 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X674_X115 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 67/84 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_X107_X375 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 68/84 models
#
#   Processing feature batch (12 features) with long lags
#   Training SGD model: long_X127_X570 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 69/84 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X730 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 70/84 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X674_X115 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 71/84 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_X107_X375 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 72/84 models
#
#   Processing feature batch (12 features) with long_odd lags
#   Training SGD model: long_odd_X127_X570 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 73/84 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X730 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 74/84 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X674_X115 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 75/84 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_X107_X375 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 76/84 models
#
#   Processing feature batch (12 features) with very_long lags
#   Training SGD model: very_long_X127_X570 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 77/84 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X730 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 78/84 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X674_X115 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 79/84 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X107_X375 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 80/84 models
#
#   Processing feature batch (12 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X127_X570 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 81/84 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X730 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 82/84 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X674_X115 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 83/84 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_X107_X375 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 84/84 models
#
#   Processing feature batch (12 features) with ultra_long lags
#   Training SGD model: ultra_long_X127_X570 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 84
#
# Model 5 Finished
#
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 29 features into 2 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/42 models
#
#   Processing feature batch (15 features) with micro lags
#   Training SGD model: micro_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 2/42 models
#
#   Processing feature batch (14 features) with micro lags
#   Training SGD model: micro_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 3/42 models
#
#   Processing feature batch (15 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 4/42 models
#
#   Processing feature batch (14 features) with micro_odd lags
#   Training SGD model: micro_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 5/42 models
#
#   Processing feature batch (15 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 6/42 models
#
#   Processing feature batch (14 features) with micro_even lags
#   Training SGD model: micro_even_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 7/42 models
#
#   Processing feature batch (15 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 8/42 models
#
#   Processing feature batch (14 features) with ultra_short lags
#   Training SGD model: ultra_short_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 9/42 models
#
#   Processing feature batch (15 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 10/42 models
#
#   Processing feature batch (14 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 11/42 models
#
#   Processing feature batch (15 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 12/42 models
#
#   Processing feature batch (14 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 13/42 models
#
#   Processing feature batch (15 features) with short lags
#   Training SGD model: short_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 14/42 models
#
#   Processing feature batch (14 features) with short lags
#   Training SGD model: short_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 15/42 models
#
#   Processing feature batch (15 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 16/42 models
#
#   Processing feature batch (14 features) with short_odd lags
#   Training SGD model: short_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 17/42 models
#
#   Processing feature batch (15 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 18/42 models
#
#   Processing feature batch (14 features) with short_even lags
#   Training SGD model: short_even_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 19/42 models
#
#   Processing feature batch (15 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 20/42 models
#
#   Processing feature batch (14 features) with short_medium lags
#   Training SGD model: short_medium_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 21/42 models
#
#   Processing feature batch (15 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 22/42 models
#
#   Processing feature batch (14 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 23/42 models
#
#   Processing feature batch (15 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 24/42 models
#
#   Processing feature batch (14 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 25/42 models
#
#   Processing feature batch (15 features) with medium lags
#   Training SGD model: medium_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 26/42 models
#
#   Processing feature batch (14 features) with medium lags
#   Training SGD model: medium_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 27/42 models
#
#   Processing feature batch (15 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 28/42 models
#
#   Processing feature batch (14 features) with medium_odd lags
#   Training SGD model: medium_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 29/42 models
#
#   Processing feature batch (15 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 30/42 models
#
#   Processing feature batch (14 features) with medium_long lags
#   Training SGD model: medium_long_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 31/42 models
#
#   Processing feature batch (15 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 32/42 models
#
#   Processing feature batch (14 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 33/42 models
#
#   Processing feature batch (15 features) with long lags
#   Training SGD model: long_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 34/42 models
#
#   Processing feature batch (14 features) with long lags
#   Training SGD model: long_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 35/42 models
#
#   Processing feature batch (15 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 36/42 models
#
#   Processing feature batch (14 features) with long_odd lags
#   Training SGD model: long_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 37/42 models
#
#   Processing feature batch (15 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 38/42 models
#
#   Processing feature batch (14 features) with very_long lags
#   Training SGD model: very_long_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 39/42 models
#
#   Processing feature batch (15 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 40/42 models
#
#   Processing feature batch (14 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 41/42 models
#
#   Processing feature batch (15 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X618 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 42/42 models
#
#   Processing feature batch (14 features) with ultra_long lags
#   Training SGD model: ultra_long_X103_X564 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 42
#
# Model 7 Finished
#
# CPU times: user 35min 7s, sys: 18min 8s, total: 53min 15s
# Wall time: 30min 56s
# 0

# %%
# %%time

train_preds = []

test_preds = []

for i in [6,8]:
    ensemble = IncrementalLagEnsemble(
      feature_batch_size=12,  # Slightly smaller batches due to more features
      lag_batch_size=5,
      n_epochs=9  # Increased to 9 as requested
    )

    ensemble.fit(X_trains[i], Y)

    train_preds.append(ensemble.predict(X_trains[i]))

    test_preds.append(ensemble.predict(X_tests[i]))

    print()
    print(f"Model {i} Finished")
    print()

    del ensemble
    gc.collect()

train_preds = pd.concat(train_preds, axis=1)
test_preds = pd.concat(test_preds, axis=1)

train_preds.to_parquet('train_preds_[6,8].parquet')
test_preds.to_parquet('test_preds_[6,8].parquet')

del test_preds, train_preds
gc.collect()
# Out:
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 35 features into 3 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/63 models
#
#   Processing feature batch (12 features) with micro lags
#   Training SGD model: micro_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 2/63 models
#
#   Processing feature batch (12 features) with micro lags
#   Training SGD model: micro_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 3/63 models
#
#   Processing feature batch (11 features) with micro lags
#   Training SGD model: micro_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 4/63 models
#
#   Processing feature batch (12 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 5/63 models
#
#   Processing feature batch (12 features) with micro_odd lags
#   Training SGD model: micro_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 6/63 models
#
#   Processing feature batch (11 features) with micro_odd lags
#   Training SGD model: micro_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 7/63 models
#
#   Processing feature batch (12 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 8/63 models
#
#   Processing feature batch (12 features) with micro_even lags
#   Training SGD model: micro_even_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 9/63 models
#
#   Processing feature batch (11 features) with micro_even lags
#   Training SGD model: micro_even_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 10/63 models
#
#   Processing feature batch (12 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 11/63 models
#
#   Processing feature batch (12 features) with ultra_short lags
#   Training SGD model: ultra_short_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 12/63 models
#
#   Processing feature batch (11 features) with ultra_short lags
#   Training SGD model: ultra_short_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 13/63 models
#
#   Processing feature batch (12 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 14/63 models
#
#   Processing feature batch (12 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 15/63 models
#
#   Processing feature batch (11 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 16/63 models
#
#   Processing feature batch (12 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 17/63 models
#
#   Processing feature batch (12 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 18/63 models
#
#   Processing feature batch (11 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 19/63 models
#
#   Processing feature batch (12 features) with short lags
#   Training SGD model: short_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 20/63 models
#
#   Processing feature batch (12 features) with short lags
#   Training SGD model: short_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 21/63 models
#
#   Processing feature batch (11 features) with short lags
#   Training SGD model: short_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 22/63 models
#
#   Processing feature batch (12 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 23/63 models
#
#   Processing feature batch (12 features) with short_odd lags
#   Training SGD model: short_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 24/63 models
#
#   Processing feature batch (11 features) with short_odd lags
#   Training SGD model: short_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 25/63 models
#
#   Processing feature batch (12 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 26/63 models
#
#   Processing feature batch (12 features) with short_even lags
#   Training SGD model: short_even_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 27/63 models
#
#   Processing feature batch (11 features) with short_even lags
#   Training SGD model: short_even_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 28/63 models
#
#   Processing feature batch (12 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 29/63 models
#
#   Processing feature batch (12 features) with short_medium lags
#   Training SGD model: short_medium_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 30/63 models
#
#   Processing feature batch (11 features) with short_medium lags
#   Training SGD model: short_medium_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 31/63 models
#
#   Processing feature batch (12 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 32/63 models
#
#   Processing feature batch (12 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 33/63 models
#
#   Processing feature batch (11 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 34/63 models
#
#   Processing feature batch (12 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 35/63 models
#
#   Processing feature batch (12 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 36/63 models
#
#   Processing feature batch (11 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 37/63 models
#
#   Processing feature batch (12 features) with medium lags
#   Training SGD model: medium_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 38/63 models
#
#   Processing feature batch (12 features) with medium lags
#   Training SGD model: medium_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 39/63 models
#
#   Processing feature batch (11 features) with medium lags
#   Training SGD model: medium_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 40/63 models
#
#   Processing feature batch (12 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 41/63 models
#
#   Processing feature batch (12 features) with medium_odd lags
#   Training SGD model: medium_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 42/63 models
#
#   Processing feature batch (11 features) with medium_odd lags
#   Training SGD model: medium_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 43/63 models
#
#   Processing feature batch (12 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 44/63 models
#
#   Processing feature batch (12 features) with medium_long lags
#   Training SGD model: medium_long_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 45/63 models
#
#   Processing feature batch (11 features) with medium_long lags
#   Training SGD model: medium_long_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 46/63 models
#
#   Processing feature batch (12 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 47/63 models
#
#   Processing feature batch (12 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 48/63 models
#
#   Processing feature batch (11 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 49/63 models
#
#   Processing feature batch (12 features) with long lags
#   Training SGD model: long_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 50/63 models
#
#   Processing feature batch (12 features) with long lags
#   Training SGD model: long_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 51/63 models
#
#   Processing feature batch (11 features) with long lags
#   Training SGD model: long_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 52/63 models
#
#   Processing feature batch (12 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 53/63 models
#
#   Processing feature batch (12 features) with long_odd lags
#   Training SGD model: long_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 54/63 models
#
#   Processing feature batch (11 features) with long_odd lags
#   Training SGD model: long_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 55/63 models
#
#   Processing feature batch (12 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 56/63 models
#
#   Processing feature batch (12 features) with very_long lags
#   Training SGD model: very_long_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 57/63 models
#
#   Processing feature batch (11 features) with very_long lags
#   Training SGD model: very_long_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 58/63 models
#
#   Processing feature batch (12 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 59/63 models
#
#   Processing feature batch (12 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 60/63 models
#
#   Processing feature batch (11 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 61/63 models
#
#   Processing feature batch (12 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X94 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 62/63 models
#
#   Processing feature batch (12 features) with ultra_long lags
#   Training SGD model: ultra_long_X76_X456 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 63/63 models
#
#   Processing feature batch (11 features) with ultra_long lags
#   Training SGD model: ultra_long_X184_X567 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 63
#
# Model 6 Finished
#
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 24 features into 2 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/42 models
#
#   Processing feature batch (12 features) with micro lags
#   Training SGD model: micro_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 2/42 models
#
#   Processing feature batch (12 features) with micro lags
#   Training SGD model: micro_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 3/42 models
#
#   Processing feature batch (12 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 4/42 models
#
#   Processing feature batch (12 features) with micro_odd lags
#   Training SGD model: micro_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 5/42 models
#
#   Processing feature batch (12 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 6/42 models
#
#   Processing feature batch (12 features) with micro_even lags
#   Training SGD model: micro_even_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 7/42 models
#
#   Processing feature batch (12 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 8/42 models
#
#   Processing feature batch (12 features) with ultra_short lags
#   Training SGD model: ultra_short_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 9/42 models
#
#   Processing feature batch (12 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 10/42 models
#
#   Processing feature batch (12 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 11/42 models
#
#   Processing feature batch (12 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 12/42 models
#
#   Processing feature batch (12 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 13/42 models
#
#   Processing feature batch (12 features) with short lags
#   Training SGD model: short_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 14/42 models
#
#   Processing feature batch (12 features) with short lags
#   Training SGD model: short_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 15/42 models
#
#   Processing feature batch (12 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 16/42 models
#
#   Processing feature batch (12 features) with short_odd lags
#   Training SGD model: short_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 17/42 models
#
#   Processing feature batch (12 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 18/42 models
#
#   Processing feature batch (12 features) with short_even lags
#   Training SGD model: short_even_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 19/42 models
#
#   Processing feature batch (12 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 20/42 models
#
#   Processing feature batch (12 features) with short_medium lags
#   Training SGD model: short_medium_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 21/42 models
#
#   Processing feature batch (12 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 22/42 models
#
#   Processing feature batch (12 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 23/42 models
#
#   Processing feature batch (12 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 24/42 models
#
#   Processing feature batch (12 features) with short_medium_even lags
#   Training SGD model: short_medium_even_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 25/42 models
#
#   Processing feature batch (12 features) with medium lags
#   Training SGD model: medium_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 26/42 models
#
#   Processing feature batch (12 features) with medium lags
#   Training SGD model: medium_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 27/42 models
#
#   Processing feature batch (12 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 28/42 models
#
#   Processing feature batch (12 features) with medium_odd lags
#   Training SGD model: medium_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 29/42 models
#
#   Processing feature batch (12 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 30/42 models
#
#   Processing feature batch (12 features) with medium_long lags
#   Training SGD model: medium_long_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 31/42 models
#
#   Processing feature batch (12 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 32/42 models
#
#   Processing feature batch (12 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 33/42 models
#
#   Processing feature batch (12 features) with long lags
#   Training SGD model: long_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 34/42 models
#
#   Processing feature batch (12 features) with long lags
#   Training SGD model: long_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 35/42 models
#
#   Processing feature batch (12 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 36/42 models
#
#   Processing feature batch (12 features) with long_odd lags
#   Training SGD model: long_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 37/42 models
#
#   Processing feature batch (12 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 38/42 models
#
#   Processing feature batch (12 features) with very_long lags
#   Training SGD model: very_long_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 39/42 models
#
#   Processing feature batch (12 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 40/42 models
#
#   Processing feature batch (12 features) with very_long_odd lags
#   Training SGD model: very_long_odd_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 41/42 models
#
#   Processing feature batch (12 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X245 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
# Progress: 42/42 models
#
#   Processing feature batch (12 features) with ultra_long lags
#   Training SGD model: ultra_long_X315_X558 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 42
#
# Model 8 Finished
#
# CPU times: user 10min 11s, sys: 5min 14s, total: 15min 26s
# Wall time: 8min
# 0

# %%
# %%time

train_preds = []

test_preds = []

for i in [9,10,11]:
    ensemble = IncrementalLagEnsemble(
      feature_batch_size=20,  # Slightly smaller batches due to more features
      lag_batch_size=5,
      n_epochs=9  # Increased to 9 as requested
    )

    ensemble.fit(X_trains[i], Y)

    train_preds.append(ensemble.predict(X_trains[i]))

    test_preds.append(ensemble.predict(X_tests[i]))

    print()
    print(f"Model {i} Finished")
    print()

    del ensemble
    gc.collect()

train_preds = pd.concat(train_preds, axis=1)
test_preds = pd.concat(test_preds, axis=1)

train_preds.to_parquet('train_preds_[9,10,11].parquet')
test_preds.to_parquet('test_preds_[9,10,11].parquet')

del test_preds, train_preds
gc.collect()
# Out:
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 17 features into 1 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/21 models
#
#   Processing feature batch (17 features) with micro lags
#   Training SGD model: micro_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 2/21 models
#
#   Processing feature batch (17 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 3/21 models
#
#   Processing feature batch (17 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 4/21 models
#
#   Processing feature batch (17 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 5/21 models
#
#   Processing feature batch (17 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 6/21 models
#
#   Processing feature batch (17 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 7/21 models
#
#   Processing feature batch (17 features) with short lags
#   Training SGD model: short_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 8/21 models
#
#   Processing feature batch (17 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 9/21 models
#
#   Processing feature batch (17 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 10/21 models
#
#   Processing feature batch (17 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 11/21 models
#
#   Processing feature batch (17 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 12/21 models
#
#   Processing feature batch (17 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 13/21 models
#
#   Processing feature batch (17 features) with medium lags
#   Training SGD model: medium_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 14/21 models
#
#   Processing feature batch (17 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 15/21 models
#
#   Processing feature batch (17 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 16/21 models
#
#   Processing feature batch (17 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 17/21 models
#
#   Processing feature batch (17 features) with long lags
#   Training SGD model: long_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 18/21 models
#
#   Processing feature batch (17 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 19/21 models
#
#   Processing feature batch (17 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 20/21 models
#
#   Processing feature batch (17 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 21/21 models
#
#   Processing feature batch (17 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X282 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 21
#
# Model 9 Finished
#
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 17 features into 1 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/21 models
#
#   Processing feature batch (17 features) with micro lags
#   Training SGD model: micro_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 2/21 models
#
#   Processing feature batch (17 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 3/21 models
#
#   Processing feature batch (17 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 4/21 models
#
#   Processing feature batch (17 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 5/21 models
#
#   Processing feature batch (17 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 6/21 models
#
#   Processing feature batch (17 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 7/21 models
#
#   Processing feature batch (17 features) with short lags
#   Training SGD model: short_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 8/21 models
#
#   Processing feature batch (17 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 9/21 models
#
#   Processing feature batch (17 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 10/21 models
#
#   Processing feature batch (17 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 11/21 models
#
#   Processing feature batch (17 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 12/21 models
#
#   Processing feature batch (17 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 13/21 models
#
#   Processing feature batch (17 features) with medium lags
#   Training SGD model: medium_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 14/21 models
#
#   Processing feature batch (17 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 15/21 models
#
#   Processing feature batch (17 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 16/21 models
#
#   Processing feature batch (17 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 17/21 models
#
#   Processing feature batch (17 features) with long lags
#   Training SGD model: long_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 18/21 models
#
#   Processing feature batch (17 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 19/21 models
#
#   Processing feature batch (17 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 20/21 models
#
#   Processing feature batch (17 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 21/21 models
#
#   Processing feature batch (17 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X281 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 21
#
# Model 10 Finished
#
# Training Incremental Lag Ensemble with Odd/Even Lag Configurations...
# Total epochs per model: 9
# Split 16 features into 1 batches
# Total lag strategies (including odd/even): 21
# Total unique lag values: 107
#
# Training micro strategy (lags: [1, 2, 3, 4, 5])
# Progress: 1/21 models
#
#   Processing feature batch (16 features) with micro lags
#   Training SGD model: micro_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_odd strategy (lags: [1, 3, 5, 7, 9])
# Progress: 2/21 models
#
#   Processing feature batch (16 features) with micro_odd lags
#   Training SGD model: micro_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training micro_even strategy (lags: [2, 4, 6, 8, 10])
# Progress: 3/21 models
#
#   Processing feature batch (16 features) with micro_even lags
#   Training SGD model: micro_even_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short strategy (lags: [6, 8, 10, 12, 15])
# Progress: 4/21 models
#
#   Processing feature batch (16 features) with ultra_short lags
#   Training SGD model: ultra_short_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_odd strategy (lags: [7, 9, 11, 13, 15, 17])
# Progress: 5/21 models
#
#   Processing feature batch (16 features) with ultra_short_odd lags
#   Training SGD model: ultra_short_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_short_even strategy (lags: [6, 8, 10, 12, 14, 16])
# Progress: 6/21 models
#
#   Processing feature batch (16 features) with ultra_short_even lags
#   Training SGD model: ultra_short_even_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short strategy (lags: [20, 25, 30, 40, 50])
# Progress: 7/21 models
#
#   Processing feature batch (16 features) with short lags
#   Training SGD model: short_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_odd strategy (lags: [21, 25, 31, 41, 51])
# Progress: 8/21 models
#
#   Processing feature batch (16 features) with short_odd lags
#   Training SGD model: short_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_even strategy (lags: [20, 24, 30, 40, 50])
# Progress: 9/21 models
#
#   Processing feature batch (16 features) with short_even lags
#   Training SGD model: short_even_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium strategy (lags: [60, 75, 90, 105, 120])
# Progress: 10/21 models
#
#   Processing feature batch (16 features) with short_medium lags
#   Training SGD model: short_medium_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_odd strategy (lags: [61, 75, 91, 105, 121])
# Progress: 11/21 models
#
#   Processing feature batch (16 features) with short_medium_odd lags
#   Training SGD model: short_medium_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training short_medium_even strategy (lags: [60, 74, 90, 104, 120])
# Progress: 12/21 models
#
#   Processing feature batch (16 features) with short_medium_even lags
#   Training SGD model: short_medium_even_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium strategy (lags: [150, 180, 210, 240, 300])
# Progress: 13/21 models
#
#   Processing feature batch (16 features) with medium lags
#   Training SGD model: medium_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_odd strategy (lags: [151, 181, 211, 241, 301])
# Progress: 14/21 models
#
#   Processing feature batch (16 features) with medium_odd lags
#   Training SGD model: medium_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long strategy (lags: [360, 420, 480, 540, 600])
# Progress: 15/21 models
#
#   Processing feature batch (16 features) with medium_long lags
#   Training SGD model: medium_long_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training medium_long_odd strategy (lags: [361, 421, 481, 541, 601])
# Progress: 16/21 models
#
#   Processing feature batch (16 features) with medium_long_odd lags
#   Training SGD model: medium_long_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long strategy (lags: [720, 840, 960, 1080, 1200])
# Progress: 17/21 models
#
#   Processing feature batch (16 features) with long lags
#   Training SGD model: long_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training long_odd strategy (lags: [721, 841, 961, 1081, 1201])
# Progress: 18/21 models
#
#   Processing feature batch (16 features) with long_odd lags
#   Training SGD model: long_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long strategy (lags: [1440, 1800, 2160, 2520, 2880])
# Progress: 19/21 models
#
#   Processing feature batch (16 features) with very_long lags
#   Training SGD model: very_long_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training very_long_odd strategy (lags: [1441, 1801, 2161, 2521, 2881])
# Progress: 20/21 models
#
#   Processing feature batch (16 features) with very_long_odd lags
#   Training SGD model: very_long_odd_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Training ultra_long strategy (lags: [3600, 4320, 5040, 5760, 7200])
# Progress: 21/21 models
#
#   Processing feature batch (16 features) with ultra_long lags
#   Training SGD model: ultra_long_bid_qty_X280 (9 epochs)
#     Epoch 1/9 completed
#     Epoch 4/9 completed
#     Epoch 7/9 completed
#
# Total models trained: 21
#
# Model 11 Finished
#
# CPU times: user 7min 34s, sys: 3min 19s, total: 10min 53s
# Wall time: 6min 27s
# 0
